# %% [markdown]
# # Week 1 - Financial Analytics Orientation
#
# ## Objective
#
# This notebook documents the Python environment setup and library verification completed as part of Week 1 of the Junior Data Analyst - Financial Analytics with Python internship.
#
# ## 1. Python Environment Verification
#
# ## 2. Project Virtual Environment
#
# ## 3. Financial Analytics Libraries
#
# ## 4. Library Import Verification
#
# ## 5. Week 1 Outcome
#
# The Python environment was successfully configured and the required financial analytics libraries were imported successfully.

# %%
import sys

print("Python Version:", sys.version)
print("Python Executable:", sys.executable)
# Out:
# Python Version: 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]
# Python Executable: s:\Projects\Financial_Analytics_Week_1\.venv\Scripts\python.exe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

print("Financial Analytics Environment")
print("-" * 40)
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", plt.matplotlib.__version__)
print("Seaborn:", sns.__version__)
print("SciPy:", scipy.__version__)
print("-" * 40)
print("All required libraries imported successfully.")
# Out:
# Financial Analytics Environment
# ----------------------------------------
# NumPy: 2.2.6
# Pandas: 2.3.3
# Matplotlib: 3.10.9
# Seaborn: 0.13.2
# SciPy: 1.15.3
# ----------------------------------------
# All required libraries imported successfully.
